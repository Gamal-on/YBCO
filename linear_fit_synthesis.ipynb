# %%
import numpy as np
import matplotlib.pyplot as plt
import tools
import fitutils as ft
import schottky_analysis
import near0_linear_analysis
import near0_nonlinear_analysis
import constants as cnt

# %% [markdown]
# ### Fit with the values of E deduced from Schottky analysis

# %%
# Between 0 and 20 K

near0_linear_analysis.final(0, 400, cnt.E_exp_10, cnt.n_exp, cnt.temperature, cnt.squared_temperature, cnt.C_div_T)
# Out:
# array([3.21724565e-01, 1.38032682e+01, 7.62826206e-03, 9.47511811e-02])

# %%
# Bewtween 200 and 400 K²

near0_linear_analysis.final(200, 400, cnt.E_exp_10, cnt.n_exp, cnt.temperature, cnt.squared_temperature, cnt.C_div_T)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 3
#       1 # Bewtween 200 and 400 K²
# ----> 3 near0_linear_analysis.final(200, 400, cnt.E_exp_10, cnt.n_exp, cnt.temperature, cnt.squared_temperature, cnt.C_div_T)
#
# File ~/Documents/internship_IMPMC/HPHT_YBCO_04_06/near0_linear_analysis.py:50, in final(a, b, E, n, x, x_carre, y)
#      48 """Warning : bounds are squared bounds"""
#      49 y_substracted = schottky_substraction(E, n, x, y)
# ---> 50 fit = linear_fit(a, b, x_carre, y_substracted)
#      51 return fit
#
# File ~/Documents/internship_IMPMC/HPHT_YBCO_04_06/near0_linear_analysis.py:24, in linear_fit(a, b, x_carre, y, err_x, err_y)
#      21 """Perform a linear fit using Monte Carlo method, between a and b (bounds)
#      22 Return the fitted values"""
#      23 x_interval, y_interval = tools.tab_interval(x_carre, y, a, b)
# ...

# %%
# Bewtween 0 and 10 K

near0_linear_analysis.final(0, 100, cnt.E_exp_10, cnt.n_exp, cnt.temperature, cnt.squared_temperature, cnt.C_div_T)
