# %%
import numpy as np
import matplotlib.pyplot as plt
import tools
import fitutils as ft
import schottky_analysis
import near0_linear_analysis
import near0_nonlinear_analysis
import constants as cnt

# %% [markdown]
# ### Fit with the values of E deduced from Schottky analysis

# %%
# Between 0 and 20 K

near0_linear_analysis.final(0, 400, cnt.E_exp_10, cnt.n_exp, cnt.temperature, cnt.squared_temperature, cnt.C_div_T)
# Out:
# array([3.20535933e-01, 1.38259298e+01, 7.34340812e-03, 8.99708327e-02])

# %%
# Bewtween 200 and 400 K²

near0_linear_analysis.final(150, 400, cnt.E_exp_10, cnt.n_exp, cnt.temperature, cnt.squared_temperature, cnt.C_div_T)
# Out:
# array([ 7.20568304e-01, -3.20850098e+01,  1.02727620e-03,  2.64522307e-01])

# %%
# Bewtween 0 and 10 K

near0_linear_analysis.final(0, 100, cnt.E_exp_10, cnt.n_exp, cnt.temperature, cnt.squared_temperature, cnt.C_div_T)
# Out:
# array([2.54587909e-01, 1.43461140e+01, 9.22679676e-03, 9.56807997e-02])

# %% [markdown]
# ### Fit the curve fit values of E and n

# %%
# Between 0 and 20 K

near0_linear_analysis.final(0, 400, cnt.E_curve_fit, cnt.n_curve_fit, cnt.temperature, cnt.squared_temperature, cnt.C_div_T)
# Out:
# array([0.48850859, 2.65402488, 0.00772019, 0.08730339])

# %%
# Between 0 and 10 K

near0_linear_analysis.final(0, 100, cnt.E_curve_fit, cnt.n_curve_fit, cnt.temperature, cnt.squared_temperature, cnt.C_div_T)
# Out:
# array([0.46728414, 2.83218122, 0.00939905, 0.09408339])

# %%
# Between 100 and 400 K²

near0_linear_analysis.final(50, 400, cnt.E_curve_fit, cnt.n_curve_fit, cnt.temperature, cnt.squared_temperature, cnt.C_div_T)
# Out:
# array([ 6.22947026e-01, -9.28454058e+00,  9.16770290e-04,  1.25606197e-01])
