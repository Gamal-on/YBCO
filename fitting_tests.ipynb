# %%
# to put in the first code cell
# %reload_ext autoreload
# %autoreload 1
# 0 disable all autoreload
# 1 only reload the one imported with %aimport lib
# 2 reload all the modules
# %aimport near0_nonlinear_analysis constants tools

import numpy as np
import matplotlib.pyplot as plt
import fitutils as ft
import scipy.optimize as opt
import fitutils as ft
import tools
import near0_nonlinear_analysis 
import constants as cnt
import near0_quadra_nonlinear

# %%
# Non linear fit between 0 K and 20 K

near0_nonlinear_analysis.plot_fit(0,400, cnt.squared_temperature, cnt.C_div_T, cnt.err_sample_HC)
# Out:
# Beta, Gamma, n, E :  0.5974037593796727 2.2766260876228883e-16 0.010219359123323432 9.300000000000482e-23

# %%
# Non linear fit between 0 K and 10 K

near0_nonlinear_analysis.plot_fit(0,100, cnt.squared_temperature, cnt.C_div_T, cnt.err_sample_HC)
# Out:
# Beta, Gamma, n, E :  0.4858077222518549 1.5992556105939442 0.010999999999999302 1.1043272257500458e-22

# %%
# Non linear fit between 0 and 15 K

near0_nonlinear_analysis.plot_fit(0,225, cnt.squared_temperature, cnt.C_div_T, cnt.err_sample_HC)
# Out:
# Beta, Gamma, n, E :  0.5345526960541916 0.1376174070684752 0.010999999782712181 1.0236217634964942e-22

# %%
# Non linear fit between 6 and 20 K

near0_nonlinear_analysis.plot_fit(36,400, cnt.squared_temperature, cnt.C_div_T, cnt.err_sample_HC)
# Out:
# Beta, Gamma, n, E :  0.5983529625812981 4.2005392845334094e-11 0.0050000000009677685 9.300000000212416e-23

# %% [markdown]
# ## Linear fit

# %%
# Linear fit between 0 and 20 K

# %% [markdown]
# ### Quadratic fit

# %%
# Between 0 and 20 K

near0_quadra_nonlinear.plot_fit_quadra(0, 400, cnt.squared_temperature, cnt.C_div_T, ([0.1, 0, 1e-3, 9.5e-23, -1 ], [0.8, 10, 1e-2, 1.1e-22, 1]))
# Out:
# Beta, Gamma, n, E, alpha :  0.43733371809300736 2.9335240167945407 0.00999989295310677 1.0978050603765534e-22 0.0005206556594971645

# %%
# Between 0 and 10 K

near0_quadra_nonlinear.plot_fit_quadra(0, 100, cnt.squared_temperature, cnt.C_div_T, ([0.1, 0, 1e-3, 9.5e-23, -1 ], [0.8, 10, 1e-2, 1.1e-22, 1]))
# Out:
# Beta, Gamma, n, E, alpha :  0.44068847309820064 3.3221268160428497 0.009790676673300192 1.0999999999999998e-22 0.00032344966519707013

# %%
# Between 10 and 20 K 

near0_quadra_nonlinear.plot_fit_quadra(36, 400, cnt.squared_temperature, cnt.C_div_T, ([0.1, 0, 1e-3, 9.9e-23, -1 ], [0.8, 10, 1e-2, 1.1e-22, 1]))
# Out:
# Beta, Gamma, n, E, alpha :  0.4547106781341214 1.3305209832976108 0.00999999999999979 1.09999999999892e-22 0.0004833919787312693
