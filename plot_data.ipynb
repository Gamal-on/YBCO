# %%
import numpy as np
import constants as cnt
import matplotlib.pyplot as plt
import tools
import schottky_analysis as sch
import constants as cnt
from functools import lru_cache
from scipy.integrate import quad
from scipy.optimize import curve_fit
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 2
#       1 import numpy as np
# ----> 2 import constants as cnt
#       3 import matplotlib.pyplot as plt
#       4 import tools
#
# File ~/Documents/internship_IMPMC/HPHT_YBCO_04_06/constants.py:62
#      59 from data_P24 import err_sample_HC_P24
#      61 squared_temperature_P24 = temperature_P24**2  # K**2
# ---> 62 hc_div_temp_P24 = sample_HC_ISIS/temperature_P24  # mJ/K**2.mol
#      63 err_hc_div_temp_P24 = err_sample_HC_ISIS/temperature_P24
#      64 err_squared_temperature_P24 = 2*temperature_P24*err_temperature_ISIS
#
# ValueError: operands could not be broadcast together with shapes (216,) (199,)

# %%
plt.figure()
plt.plot(cnt.temperature_HPHT, cnt.sample_HC_HPHT, ".g", label="HPHT")
plt.plot(cnt.temperature_ISIS,cnt.sample_HC_ISIS, ".r", label="overdoped")
plt.legend()

# %%
plt.figure()
plt.plot(cnt.squared_temperature_HPHT, cnt.hc_div_temp_HPHT, ".g", label="HPHT")
plt.plot(cnt.squared_temperature_ISIS,cnt.hc_div_temp_ISIS, ".r", label="overdoped")
pl
plt.grid(True)
plt.xlabel("Carré de la température (en K²)")
plt.ylabel("C/T (en mJ/K²/mol)")
plt.legend()

# %%
squared_temp_HPHT_bounded, hc_HPHT_bounded = tools.tab_interval(cnt.squared_temperature_HPHT, cnt.hc_div_temp_HPHT, 0, 400)
squared_temp_ISIS_bounded, hc_ISIS_bounded = tools.tab_interval(cnt.squared_temperature_ISIS, cnt.hc_div_temp_ISIS, 0, 400)

plt.figure()
plt.plot(squared_temp_HPHT_bounded, hc_HPHT_bounded, ".g", label="HPHT")
plt.plot(squared_temp_ISIS_bounded,hc_ISIS_bounded, ".r", label="overdoped")
plt.legend()
