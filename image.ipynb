# %%
import numpy as np
import matplotlib.pyplot as plt
import data_image as dt

# %%
plt.figure()
plt.plot(dt.x_La214_0259, dt.y_La214_0259, ".b", label="La214, x=0.259")
plt.plot(dt.x_L214_0290, dt.x_L214_0290, "r.", label="La214, x = 0.290")
plt.plot(dt.x_Y123_carre, dt.y_Y123_carre, "+k", label="Y123 opt doped")
#plt.plot(dt.x_HPO, dt.y_HPO, ".k", label="HPO")
#plt.plot(dt.x_La214, dt.y_La214, "g.", label="La214 opt doped")
plt.grid(True)
plt.legend()
